# %% [markdown]
# Location bug still exists...try to filter out <2 words ones?
#
# -*- coding: utf-8 -*-
#
# """
#
# Created on Thu Aug 23, 2020
#
# @author: Rohitashwa
#
# @Credits: loren ( https://github.com/jjeffus/gofundme)
#
# """

# %%
# !pip install selenium
# !pip install bs4
# !pip install requests
# !pip install pytest-shutil

# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from time import sleep
import requests
import re
import shutil # For image download

# %%
mydf = pd.read_csv('data/GFM_url_list.csv', sep = '\t')
headers = ["Url", "Category","Position", "Title", "Location", "Organiser","Amount_Raised", "Goal", "Duration", "Text", "Image"]
mydf = mydf.reindex(columns = headers)
print(mydf.shape)
mydf.head()
# Out:
# (12000, 11)
#                                                  Url Category  Position  \
# 0  https://www.gofundme.com/f/uzxprm-helping-the-...  Animals         0
# 1  https://www.gofundme.com/f/please-support-for-...  Animals         0
# 2  https://www.gofundme.com/f/help-thirsty-koalas...  Animals         0
# 3  https://www.gofundme.com/f/help-save-kangaroo-...  Animals         1
# 4                  https://www.gofundme.com/f/REWILD  Animals         1
#
#    Title  Location  Organiser  Amount_Raised  Goal  Duration  Text  Image
# 0    NaN       NaN        NaN            NaN   NaN       NaN   NaN    NaN
# 1    NaN       NaN        NaN            NaN   NaN       NaN   NaN    NaN
# 2    NaN       NaN        NaN            NaN   NaN       NaN   NaN    NaN
# 3    NaN       NaN        NaN            NaN   NaN       NaN   NaN    NaN
# 4    NaN       NaN        NaN            NaN   NaN       NaN   NaN    NaN

# %%
# mydf.iloc[0]

# %% [markdown]
# # Scrape Individual URLs

# %%
listInvalidCampaign = []
lstScrapingError = []

def scrape_url(row_index, tid = "mainThread"):
    print("Scraping url %s" %(row_index+1))
    
    single_row = mydf.iloc[row_index]
    url = single_row["Url"]
    category = single_row["Category"]
    position = single_row["Position"]

    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'lxml')
    
    temp_df = pd.DataFrame(columns = headers)
    
#     invalidCampaign = soup.find('div', attrs={'class': 'm-campaign-sidebar-notification m-well m-well--sand'})
    
#     if(invalidCampaign is not None):
#         text_container =  soup.find('meta', attrs={'name': 'description'})
#         print(text_container['content'])
#         listInvalidCampaign.append(row_index)
#         return "Invalid Campaign"
    
    try:
        # Description
        text_container =  soup.find('meta', attrs={'name': 'description'})
        try:
            all_text = text_container['content']
        except:
            all_text = np.nan

        if(all_text is np.nan )or(all_text == "We're sorry, but that campaign cannot be found. Please check the link URL and try again."):
            print(tid+' ('+str(row_index)+') -> '+all_text)
            listInvalidCampaign.append(row_index)
            temp_df = pd.DataFrame(columns = headers)
            return(temp_df)

        # Title
        try:
            title = soup.find("title").text
        except:
            title = np.nan

        # Organiser & Location
        try:
            t = soup.find_all("div",{"class":"p-campaign-members"})[0]
            organiser = t.find_all("div",{"class": "m-person-info-name"})[0].text.replace('\xa0','')
            location = ""
            if(len(t.find_all("div",{"class": "text-small"})) > 3):
                location = t.find_all("div",{"class": "text-small"})[2].text.replace('\xa0','')
            else:
                location = t.find_all("div",{"class": "text-small"})[1].text.replace('\xa0','')
        except:
            organiser = np.nan
            location = np.nan

        # Amount Raised and Goal
        try:
            t = soup.find("div",{"class":"p-campaign-sidebar"})
            amount = t.find("div",{"class": "o-campaign-sidebar-progress-meter m-progress-meter"})
            amountRaised = amount.text.split()[0]
            goal = amount.text.split()[-2]
        except:
            amountRaised = np.nan
            goal = np.nan

        # All Text
        soup.find('div', {'class': "p-campaign-description"})
        text = soup.find('div', {'class': "o-campaign-story mt-three-halves"}).text.replace('\xa0','').replace('\n','')
        text

        # Duration of Fundraising
        try:
            t = soup.find("div",{"class": "p-campaign-description"})
            startDate = ' '.join(t.find("li",{"class": "m-meta-list-item"}).text.split()[1::])
            startDate = (pd.to_datetime(startDate)).date()
            duration = (pd.datetime.now().date() - startDate).days
        except:
            duration = np.nan

        #Image
        try:
            img_container =  soup.find('meta', attrs={'property': 'og:image'})
            image_url = img_container['content']

            img_filename = "data/images/"+image_url.split("/")[-1]

            # Open the url image, set stream to True, this will return the stream content.
            r = requests.get(image_url, stream = True)

            # Check if the image was retrieved successfully
            if r.status_code == 200:
                # Set decode_content value to True, otherwise the downloaded image file's size will be zero.
                r.raw.decode_content = True

                # Open a local file with wb ( write binary ) permission.
                with open(img_filename,'wb') as f:
                    shutil.copyfileobj(r.raw, f)
        except:
            img_filename = np.nan

    #     # FB likes and Shares    
    #     try:
    #         FB_shares_container = soup.find_all("strong", {"class":"js-share-count-text"})
    #         FB_shares = FB_shares_container[0].text.splitlines()
    #         FB_shares = FB_shares[1].replace(" ", "").replace("\xa0", "")
    #     except:
    #         FB_shares = np.nan

    #     try:
    #         hearts_container = soup.find_all("div", {"class":"campaign-sp campaign-sp--heart fave-num"})
    #         hearts = hearts_container[0].text
    #     except:
    #         hearts = np.nan

        temp_row = np.array([[url, category, position, title, location, organiser, amountRaised, goal, duration, text, img_filename]])
        temp_df = pd.DataFrame(temp_row, columns = headers)

        return(temp_df)
    
    except:
        lstScrapingError.append(row_index)
        return tid+' ('+str(row_index)+') -> '+"Scraping Error"

# %% [markdown]
# ## Multithreaded Version

# %%
def scrape_all_urlsV2(params):
    start, end , tid = params
    print("Started Scraping for Thread: "+str(tid))
    
    finaldf = pd.DataFrame(columns = headers)
    for i in range(start, end):
        try:
            sleep(6)
            t = scrape_url(i, tid)
            if(type(t) != str):
                finaldf = pd.concat([finaldf,t], ignore_index = True)
            else:
                print(t)
        except Exception as e:
            print("Thread ID "+str(tid),getattr(e, 'message', repr(e)))
    return finaldf
    
#     for i in range(start, end):
#         try:
#             t = scrape_url(i)
#             temp_df = pd.concat([temp_df,t], ignore_index = True)
#         except:
#             try:
#                 sleep(5)
#                 t = scrape_url(i)
#                 temp_df = pd.concat([temp_df,t], ignore_index = True)
#             except:
#                 print("Thread ID "+str(tid)+": Cant Scrape Row: "+str(i))

# %%
#Distribute regions for the multiple threads
def BatchGenerator(start_index, end_index, batch_size):
    tid = 0
    for step in range(start_index,end_index,batch_size):
        tid = tid+1
        end = (step+batch_size) if ((step+batch_size) < end_index) else (end_index)
        yield (step, end, 'Thread_'+str(tid))

# %%
for i in BatchGenerator(0, mydf.shape[0], 400):
# for i in BatchGenerator(0, 50, 10):
    print(i)
# Out:
# (0, 400, 'Thread_1')
# (400, 800, 'Thread_2')
# (800, 1200, 'Thread_3')
# (1200, 1600, 'Thread_4')
# (1600, 2000, 'Thread_5')
# (2000, 2400, 'Thread_6')
# (2400, 2800, 'Thread_7')
# (2800, 3200, 'Thread_8')
# (3200, 3600, 'Thread_9')
# (3600, 4000, 'Thread_10')
# (4000, 4400, 'Thread_11')
# (4400, 4800, 'Thread_12')
# (4800, 5200, 'Thread_13')
# (5200, 5600, 'Thread_14')
# (5600, 6000, 'Thread_15')
# (6000, 6400, 'Thread_16')
# (6400, 6800, 'Thread_17')
# (6800, 7200, 'Thread_18')
# (7200, 7600, 'Thread_19')
# (7600, 8000, 'Thread_20')
# (8000, 8400, 'Thread_21')
# (8400, 8800, 'Thread_22')
# (8800, 9200, 'Thread_23')
# (9200, 9600, 'Thread_24')
# (9600, 10000, 'Thread_25')
# (10000, 10400, 'Thread_26')
# (10400, 10800, 'Thread_27')
# (10800, 11200, 'Thread_28')
# (11200, 11600, 'Thread_29')
# (11600, 12000, 'Thread_30')

# %%
# Online Mode
_ = pd.DataFrame(columns = headers)
_.to_csv("data/GFM_data.csv",sep = '\t')


finaldf = pd.DataFrame(columns=headers)

# Multi-Threaded
import time
import concurrent.futures

start_record = 0
end_record = mydf.shape[0]
batch_size = 500

t0= time.time()

with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:
    futures = [executor.submit(scrape_all_urlsV2, param) for param in BatchGenerator(start_record, end_record, batch_size)]
    return_value = [f.result() for f in futures]

    rowCount = 1
    for k in return_value:
        finaldf = pd.concat([finaldf,k], ignore_index = True)
        rowCount = rowCount + batch_size

t1= time.time() -t0
# Out:
# Started Scraping for Thread: Thread_1
# Started Scraping for Thread: Thread_2
# Started Scraping for Thread: Thread_3
# Started Scraping for Thread: Thread_4
# Started Scraping for Thread: Thread_5
# Started Scraping for Thread: Thread_6
# Started Scraping for Thread: Thread_7
# Started Scraping for Thread: Thread_8
# Started Scraping for Thread: Thread_9
# Started Scraping for Thread: Thread_10
# Started Scraping for Thread: Thread_11
# Started Scraping for Thread: Thread_12
# Started Scraping for Thread: Thread_13
# Started Scraping for Thread: Thread_14
# Started Scraping for Thread: Thread_15
# Started Scraping for Thread: Thread_16
# Started Scraping for Thread: Thread_17
# Started Scraping for Thread: Thread_18
# Started Scraping for Thread: Thread_19
# Started Scraping for Thread: Thread_20
# Scraping url 1
# Scraping url 501
# Scraping url 1001
# Scraping url 1501
# Scraping url 2001
# Scraping url 2501
# Scraping url 3001
# Scraping url 4001
# Scraping url 3501
# Scraping url 4501
# Scraping url 5001
# Scraping url 6001
# Scraping url 6501Scraping url 5501
# Scraping url 7001
#
# Scraping url 7501Scraping url 8001
#
# Scraping url 8501
# Scraping url 9501
# Scraping url 9001
# Thread_17 (8000) -> We're sorry, but that campaign cannot be found. Please check the link URL and try again.
# Thread_19 (9000) -> We're sorry, but that campaign cannot be found. Please check the link URL and try again.
# Thread_1 (0) -> We're sorry, but that campaign cannot be found. Please check the link URL and try again.
# Thread_18 (8500) -> Scraping Error
# <ipython-input-3-8885488b2d17>:78: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   duration = (pd.datetime.now().date() - startDate).days
# Thread_3 (1000) -> Scraping Error
# Scraping url 8002
# Scraping url 9002
# Scraping url 2
# Scraping url 8502
# Scraping url 1002
# Scraping url 7002
# Scraping url 1502
# Scraping url 6002
# Scraping url 7502
# Scraping url 2002
# Scraping url 2502
# Scraping url 5002
# Scraping url 3502
# Scraping url 6502
# Scraping url 5502
# Scraping url 4002
# Scraping url 3002
# Scraping url 502
# Scraping url 9502Scraping url 4502
#
# Thread_19 (9001) -> We're sorry, but that campaign cannot be found. Please check the link URL and try again.
# Thread_1 (1) -> We're sorry, but that campaign cannot be found. Please check the link URL and try again.
# Thread_15 (7001) -> We're sorry, but that campaign cannot be found. Please check the link URL and try again.
# Scraping url 9003
# Scraping url 3
# Scraping url 8003
# Scraping url 7003
# Scraping url 4503
# Scraping url 1003
# Thread_15 (7002) -> We're sorry, but that campaign cannot be found. Please check the link URL and try again.
# Scraping url 6003
# Scraping url 8503
# Scraping url 503
# Scraping url 5503
# Scraping url 6503
# Scraping url 3003
# Scraping url 3503
# Scraping url 2503
# Scraping url 4003
# Scraping url 9503
# Scraping url 5003
# Scraping url 7503
# Scraping url 1503
# Scraping url 9004
# Scraping url 7004
# Scraping url 4504
# Scraping url 4
# Scraping url 8004
# Thread_19 (9003) -> We're sorry, but that campaign cannot be found. Please check the link URL and try again.
# Scraping url 1004
# Scraping url 6004
# Thread_3 (1003) -> We're sorry, but that campaign cannot be found. Please check the link URL and try again.
# Scraping url 8504
# Scraping url 4004
# Scraping url 504
# Scraping url 3504
# Scraping url 5504
# Scraping url 3004
# Scraping url 2504
# Scraping url 5004
# Scraping url 1504
# Scraping url 7504Scraping url 9504
#
# Scraping url 6504
# Scraping url 9005
# Scraping url 7005
# Scraping url 4505
# Scraping url 1005
# Scraping url 8005
# Scraping url 5
# Scraping url 8505
# Scraping url 6005
# Scraping url 2505
# Scraping url 505
# Scraping url 3505
# Scraping url 4005
# Scraping url 7505
# Scraping url 3005
# Scraping url 5005
# Scraping url 5505
# Scraping url 6505
# Scraping url 9505
# Scraping url 1505
# Scraping url 9006
# Scraping url 7006
# Scraping url 2003
# Scraping url 1006
# Scraping url 8006
# Scraping url 6
# Scraping url 8506
# Scraping url 6006
# Scraping url 506
# Scraping url 2506
# Scraping url 5506
# Scraping url 3506
# Scraping url 5006
# Scraping url 3006
# Scraping url 4006
# Scraping url 7506
# Scraping url 1506
# Scraping url 9506
# Scraping url 6506
# Scraping url 9007
# Scraping url 7007
# Scraping url 2004
# Scraping url 7
# Scraping url 3507
# Scraping url 1007
# Scraping url 8007
# Scraping url 2507Scraping url 507
#
# Scraping url 4007
# Scraping url 6007
# Scraping url 8507
# Scraping url 5507
# Scraping url 3007
# Scraping url 7507
# Scraping url 5007
# Thread_3 (1006) -> We're sorry, but that campaign cannot be found. Please check the link URL and try again.
# Scraping url 9507
# Scraping url 1507
# Scraping url 6507
# Scraping url 9008
# Scraping url 2005
# Scraping url 7008
# Scraping url 1008
# Scraping url 8
# Thread_3 (1007) -> We're sorry, but that campaign cannot be found. Please check the link URL and try again.
# Scraping url 3508
# Scraping url 6008
# Scraping url 7508
# Scraping url 3008
# Scraping url 2508
# Scraping url 508
# Scraping url 8508
# Scraping url 5008
# Scraping url 4008
# Scraping url 5508
# Scraping url 8008
# Scraping url 9508
# Scraping url 4506
# Scraping url 1508
# Scraping url 6508
# Scraping url 1009
# Scraping url 2006
# Scraping url 7009
# Scraping url 9009
# Scraping url 9
# Thread_3 (1008) -> We're sorry, but that campaign cannot be found. Please check the link URL and try again.
# Scraping url 3509
# Scraping url 509
# Scraping url 4009
# Scraping url 5509
# Scraping url 8009
# Scraping url 8509
# Scraping url 3009
# Scraping url 2509
# Scraping url 6009
# Scraping url 5009
# Scraping url 1010
# Scraping url 7509
# Thread_17 (8008) -> Scraping Error
# Thread_3 (1009) -> We're sorry, but that campaign cannot be found. Please check the link URL and try again.
# Scraping url 4507
# Scraping url 9509
# Scraping url 6509
# Scraping url 9010
# Scraping url 1509
# Scraping url 2007
# Scraping url 7010
# Scraping url 10
# Scraping url 3510
# Thread_4 (1508) -> Scraping Error
# Scraping url 510
# Scraping url 8010
# Scraping url 3010
# Scraping url 4010
# Scraping url 8510
# Scraping url 1011
# Scraping url 5510
# Scraping url 5010
# Scraping url 6010
# Scraping url 7510
# Scraping url 2510
# Thread_3 (1010) -> We're sorry, but that campaign cannot be found. Please check the link URL and try again.
# Scraping url 9510
# Scraping url 4508
# Scraping url 1510
# Scraping url 2008
# Scraping url 6510
# Scraping url 9011
# Scraping url 7011
# Scraping url 11
# Scraping url 3511
# Scraping url 511
# Scraping url 8011
# Scraping url 1012
# Scraping url 3011
# Scraping url 8511
# Scraping url 4011
# Scraping url 5011
# Scraping url 5511
# Scraping url 6011
# Scraping url 7511
# Scraping url 9511
# Scraping url 2511
# Scraping url 1511
# Scraping url 4509
# Scraping url 2009
# Scraping url 6511
# Scraping url 9012
# Scraping url 7012
# Scraping url 3512
# Scraping url 12
# Scraping url 512
# Scraping url 1013
# Scraping url 3012
# Scraping url 8512
# Scraping url 8012
# Scraping url 4012
# Scraping url 5012
# Scraping url 5512
# Scraping url 7512
# Scraping url 6012
# Scraping url 2512
# Scraping url 9512
# Scraping url 4510
# Scraping url 1512
# Scraping url 7013
# Scraping url 2010
# Scraping url 6512
# Scraping url 9013
# Scraping url 3513
# Scraping url 13
# Scraping url 513
# Scraping url 1014
# Scraping url 3013
# Scraping url 8513
# Scraping url 5013
# Scraping url 8013
# Scraping url 4013
# Scraping url 5513
# Scraping url 7513
# Scraping url 6013
# Scraping url 2513
# Scraping url 9513
# Scraping url 4511
# Scraping url 1513
# Scraping url 7014
# Scraping url 6513Scraping url 3514
#
# Scraping url 2011
# Scraping url 9014
# Scraping url 14
# Scraping url 7537
# Scraping url 3537
# Scraping url 8037
# Scraping url 4034
# Scraping url 9038
# Scraping url 6034
# Scraping url 35
# Scraping url 9535
# Scraping url 3037
# Scraping url 538
# Scraping url 4534
# Scraping url 1538
# Scraping url 6538
# Scraping url 7038
# Scraping url 5037
# Scraping url 3538
# Scraping url 1037
# Scraping url 7538
# Scraping url 9039
# Scraping url 8038
# Scraping url 4035
# Scraping url 6035
# Scraping url 36
# Scraping url 9536
# Scraping url 4535
# Scraping url 6539
# Scraping url 1539
# Scraping url 7039
# Scraping url 1038
# Scraping url 5038
# Scraping url 4036
# Scraping url 3539
# Scraping url 6036
# Scraping url 8039
# Scraping url 37
# Scraping url 9537
# Thread_2 (537) -> Scraping Error
# Scraping url 4536
# Scraping url 5537
# Scraping url 2536
# Scraping url 8537
# Thread_11 (5037) -> Scraping Error
# Scraping url 1540
# Scraping url 2033
# Scraping url 1039
# Scraping url 539
# Scraping url 4037
# Scraping url 3540
# Scraping url 8040
# Scraping url 6037
# Scraping url 9538
# Scraping url 38
# Scraping url 3038
# Scraping url 9040
# Scraping url 7539
# Scraping url 5039
# Scraping url 4537
# Scraping url 5538
# Scraping url 7040Scraping url 2537
#
# Scraping url 6540
# Scraping url 8538
# Scraping url 1541
# Scraping url 2034
# Scraping url 1040
# Scraping url 540
# Scraping url 3541
# Scraping url 4038
# Scraping url 39
# Scraping url 9539
# Scraping url 6038
# Scraping url 9041
# Scraping url 3039
# Scraping url 7540
# Scraping url 2538
# Scraping url 7041
# Scraping url 5040
# Scraping url 6541
# Scraping url 8539
# Scraping url 5539
# Scraping url 4538
# Scraping url 1542
# Scraping url 2035
# Scraping url 1041
# Scraping url 541
# Scraping url 3542
# Scraping url 4039
# Scraping url 6039
# Scraping url 40
# Scraping url 9540
# Scraping url 2539
# Scraping url 8540
# Scraping url 9042
# Scraping url 5041
# Scraping url 7042
# Scraping url 3040
# Scraping url 7541
# Scraping url 5540
# Scraping url 4539
# Scraping url 2036
# Thread_18 (8539) -> Scraping Error
# Scraping url 6542
# Scraping url 1543
# Scraping url 1042
# Scraping url 542
# Scraping url 8041
# Scraping url 8541
# Scraping url 41
# Scraping url 9043
# Scraping url 4040
# Scraping url 6040
# Scraping url 3543
# Scraping url 9541
# Scraping url 3041
# Scraping url 5042
# Scraping url 2540
# Scraping url 7043
# Scraping url 7542
# Scraping url 4540
# Scraping url 5541
# Scraping url 2037
# Scraping url 1544
# Scraping url 6543
# Scraping url 543
# Scraping url 8042
# Scraping url 9044
# Scraping url 42
# Scraping url 8542
# Scraping url 4041
# Scraping url 3544
# Scraping url 9542
# Scraping url 7543
# Scraping url 2541
# Scraping url 3042
# Scraping url 5542
# Scraping url 7044
# Scraping url 4541
# Scraping url 1545
# Scraping url 6544
# Scraping url 2038
# Scraping url 8043
# Scraping url 544
# Scraping url 9045
# Scraping url 43
# Scraping url 8543
# Scraping url 4042
# Scraping url 3545
# Scraping url 7544
# Scraping url 1043
# Scraping url 9543
# Scraping url 2542
# Scraping url 8128
# Scraping url 7629
# Scraping url 6625
# Scraping url 4127
# Scraping url 8630
# Scraping url 1126
# Scraping url 4625
# Scraping url 7130
# Scraping url 5117
# Scraping url 9130
# Scraping url 2121
# Scraping url 127
# Scraping url 5623
# Scraping url 2625
# Scraping url 9627
# Scraping url 3632
# Scraping url 8129
# Scraping url 6626
# Scraping url 2122Scraping url 7630
#
# Scraping url 4128
# Scraping url 8631
# Scraping url 128
# Scraping url 631
# Scraping url 4626
# Scraping url 1630
# Scraping url 9131
# Scraping url 7131
# Scraping url 2626
# Scraping url 5624
# Scraping url 1127
# Scraping url 5118
# Scraping url 9628

# %%
finaldf.to_csv('data/GFM_dataV2.csv',sep = '\t', index = False)
finaldf.to_csv('data/GFM_data.csv',sep = '\t', index = False, mode = 'a', header = False)
finaldf
# Out:
#                                                     Url   Category Position  \
# 0     https://www.gofundme.com/f/money-to-buy-hearin...    Medical        0
# 1       https://www.gofundme.com/f/justiceforjacobblake    Medical        1
# 2     https://www.gofundme.com/f/official-navajo-nat...    Medical        2
# 3     https://www.gofundme.com/f/emergenza-covid-ces...    Medical        2
# 4          https://www.gofundme.com/f/save-nil039s-life    Medical        2
# ...                                                 ...        ...      ...
# 6785     https://www.gofundme.com/f/project-ray-of-hope  Volunteer      331
# 6786  https://www.gofundme.com/f/to-feed-dailywagers...  Volunteer      332
# 6787  https://www.gofundme.com/f/contribution-to-com...  Volunteer      332
# 6788  https://www.gofundme.com/f/covid19-emergency-f...  Volunteer      332
# 6789  https://www.gofundme.com/f/help-feed-the-indig...  Volunteer      333
#
#                                                   Title  \
# 0     Fundraiser by Chandan Shivu Kumar : Money to b...
# 1     Fundraiser by Julia Jackson : Justice for Jaco...
# 2     Fundraiser for Pearline Kirk by Navajo Nation ...
# 3     Fundraiser by Gloria Zavatta : Cesvi per l'osp...
# 4        Fundraiser by Berk Atikoğlu : Save Nil's Life!
# ...                                                 ...
# 6785  Fundraiser by Nadia Afrin : Food assistance fo...
# 6786  Fundraiser by Lily Thapa : To Feed Daily-Wager...
# 6787  Fundraiser by Mahber Selam : COVID-19 and agai...
# 6788  Fundraiser for Niñez con Futuro by Cindy Zetin...
# 6789  Fundraiser for Gerardo Marquez by Andrea Marqu...
#
#                       Location       Organiser Amount_Raised        Goal  \
# 0                          nan             nan          $250        $250
# 1                  Kenosha, WI   Julia Jackson    $2,252,260  $3,000,000
# 2              Window Rock, AZ   Navajo Nation    $1,770,760  $1,000,000
# 3                  Team member  Gloria Zavatta    €1,506,210  €1,500,000
# 4                 Brooklyn, NY   Berk Atikoğlu    $2,402,980  $2,400,000
# ...                        ...             ...           ...         ...
# 6785            Washington, DC     Nadia Afrin        $7,035     $12,000
# 6786            Somerville, MA      Lily Thapa        $7,034     $20,000
# 6787  Liendert, Rustenburg, NL    Mahber Selam        €7,002     €50,000
# 6788           Sioux Falls, SD    Cindy Zetino        $6,998     $10,000
# 6789              Cerritos, CA  Andrea Marquez        $6,985     $10,000
#
#      Duration                                               Text  \
# 0         236  Hello there, I'm a random guy from India who's...
# 1          15  On August 23rd my son was shot multiple times ...
# 2         127  The Navajo Nation COVID-19 Fund has been estab...
# 3         182  Per aggiornamenti su come stiamo impiegando i ...
# 4         182  Save Nil’s Life ! I am starting a campaign for...
# ...       ...                                                ...
# 6785      116  We are raising funds to support 200 Bangladesh...
# 6786      143  Women for Human Rights Group is an organizatio...
# 6787      143  We want mobilize the Eritreans in Tigray and e...
# 6788      108  Thousands of families are currently facing eco...
# 6789      143  The world is undoubtedly going through a stran...
#
#                                              Image
# 0     data/images/44793298_1579175168658123_r.jpeg
# 1      data/images/50669212_1598282954644748_r.jpg
# 2     data/images/47855360_1589149838795170_r.jpeg
# 3     data/images/46073102_1583841007387069_r.jpeg
# 4     data/images/46072754_1583838455417877_r.jpeg
# ...                                            ...
# 6785  data/images/48097994_1589567702790696_r.jpeg
# 6786  data/images/47489998_1587219372600672_r.jpeg
# 6787  data/images/47496222_1588529991103718_r.jpeg
# 6788   data/images/48270674_1594729069827005_r.jpg
# 6789  data/images/47499708_1587250982349137_r.jpeg
#
# [6790 rows x 11 columns]

# %% [markdown]
# {
#   "data/GFM_url_7k.csv": {
#     "InvalidCampaign": [0,1,1002,3,4,1005,1006,1007,1008,1009,2925,2926,5922,1923,3925,3926,3927,3928,3929,3930,3931,3932,3933],
#     "ScrapingError": [1023,2028,2033,2038,46,2050,3069,2072,5074,1093,2110,6110,2116,124,4129,1131,1132,6161,3183,4190,195,1201,6202,3202,202,1216,3219,1233,5266,6284,4290,3296,5299,1301,2304,305,306,318,3321,2334,338,6343,5349,5361,4379,4391,2398,1409,5419,5425,2428,432,2444,3442,5447,2479,4487,489,2504,1507,4519,2526,5528,2545,1550,3567,5571,2591,593,6600,2625,5641,4648,5662,2674,1673,1679,684,4694,711,2729,1749,2758,2765,4790,6792,2806,1803,816,6821,2842,842,2867,1865,5874,2884,883,2891,2895,1901,4933,933,1955,955,974,981,1986,5992,999]
#   },
#   "data/GFM_url_list": {
#       "InvalidCampaign": ,
#     "ScrapingError":
#   }
# }

# %%
listInvalidCampaign
# Out:
# [0,
#  1,
#  1002,
#  3,
#  4,
#  1005,
#  1006,
#  1007,
#  1008,
#  1009,
#  2925,
#  2926,
#  5922,
#  1923,
#  3925,
#  3926,
#  3927,
#  3928,
#  3929,
#  3930,
#  3931,
#  3932,
#  3933]

# %%
lstScrapingError
# Out:
# [1023,
#  2028,
#  2033,
#  2038,
#  46,
#  2050,
#  3069,
#  2072,
#  5074,
#  1093,
#  2110,
#  6110,
#  2116,
#  124,
#  4129,
#  1131,
#  1132,
#  6161,
#  3183,
#  4190,
#  195,
#  1201,
#  6202,
#  3202,
#  202,
#  1216,
#  3219,
#  1233,
#  5266,
#  6284,
#  4290,
#  3296,
#  5299,
#  1301,
#  2304,
#  305,
#  306,
#  318,
#  3321,
#  2334,
#  338,
#  6343,
#  5349,
#  5361,
#  4379,
#  4391,
#  2398,
#  1409,
#  5419,
#  5425,
#  2428,
#  432,
#  2444,
#  3442,
#  5447,
#  2479,
#  4487,
#  489,
#  2504,
#  1507,
#  4519,
#  2526,
#  5528,
#  2545,
#  1550,
#  3567,
#  5571,
#  2591,
#  593,
#  6600,
#  2625,
#  5641,
#  4648,
#  5662,
#  2674,
#  1673,
#  1679,
#  684,
#  4694,
#  711,
#  2729,
#  1749,
#  2758,
#  2765,
#  4790,
#  6792,
#  2806,
#  1803,
#  816,
#  6821,
#  2842,
#  842,
#  2867,
#  1865,
#  5874,
#  2884,
#  883,
#  2891,
#  2895,
#  1901,
#  4933,
#  933,
#  1955,
#  955,
#  974,
#  981,
#  1986,
#  5992,
#  999]

# %%
pd.read_csv("data/GFM_data.csv",sep = '\t')
# Out:
#                                                     Url   Category  Position  \
# 0     https://www.gofundme.com/f/money-to-buy-hearin...    Medical         0
# 1       https://www.gofundme.com/f/justiceforjacobblake    Medical         1
# 2     https://www.gofundme.com/f/official-navajo-nat...    Medical         2
# 3     https://www.gofundme.com/f/emergenza-covid-ces...    Medical         2
# 4          https://www.gofundme.com/f/save-nil039s-life    Medical         2
# ...                                                 ...        ...       ...
# 6785     https://www.gofundme.com/f/project-ray-of-hope  Volunteer       331
# 6786  https://www.gofundme.com/f/to-feed-dailywagers...  Volunteer       332
# 6787  https://www.gofundme.com/f/contribution-to-com...  Volunteer       332
# 6788  https://www.gofundme.com/f/covid19-emergency-f...  Volunteer       332
# 6789  https://www.gofundme.com/f/help-feed-the-indig...  Volunteer       333
#
#                                                   Title  \
# 0     Fundraiser by Chandan Shivu Kumar : Money to b...
# 1     Fundraiser by Julia Jackson : Justice for Jaco...
# 2     Fundraiser for Pearline Kirk by Navajo Nation ...
# 3     Fundraiser by Gloria Zavatta : Cesvi per l'osp...
# 4        Fundraiser by Berk Atikoğlu : Save Nil's Life!
# ...                                                 ...
# 6785  Fundraiser by Nadia Afrin : Food assistance fo...
# 6786  Fundraiser by Lily Thapa : To Feed Daily-Wager...
# 6787  Fundraiser by Mahber Selam : COVID-19 and agai...
# 6788  Fundraiser for Niñez con Futuro by Cindy Zetin...
# 6789  Fundraiser for Gerardo Marquez by Andrea Marqu...
#
#                       Location       Organiser Amount_Raised        Goal  \
# 0                          NaN             NaN          $250        $250
# 1                  Kenosha, WI   Julia Jackson    $2,252,260  $3,000,000
# 2              Window Rock, AZ   Navajo Nation    $1,770,760  $1,000,000
# 3                  Team member  Gloria Zavatta    €1,506,210  €1,500,000
# 4                 Brooklyn, NY   Berk Atikoğlu    $2,402,980  $2,400,000
# ...                        ...             ...           ...         ...
# 6785            Washington, DC     Nadia Afrin        $7,035     $12,000
# 6786            Somerville, MA      Lily Thapa        $7,034     $20,000
# 6787  Liendert, Rustenburg, NL    Mahber Selam        €7,002     €50,000
# 6788           Sioux Falls, SD    Cindy Zetino        $6,998     $10,000
# 6789              Cerritos, CA  Andrea Marquez        $6,985     $10,000
#
#       Duration                                               Text  \
# 0        236.0  Hello there, I'm a random guy from India who's...
# 1         15.0  On August 23rd my son was shot multiple times ...
# 2        127.0  The Navajo Nation COVID-19 Fund has been estab...
# 3        182.0  Per aggiornamenti su come stiamo impiegando i ...
# 4        182.0  Save Nil’s Life ! I am starting a campaign for...
# ...        ...                                                ...
# 6785     116.0  We are raising funds to support 200 Bangladesh...
# 6786     143.0  Women for Human Rights Group is an organizatio...
# 6787     143.0  We want mobilize the Eritreans in Tigray and e...
# 6788     108.0  Thousands of families are currently facing eco...
# 6789     143.0  The world is undoubtedly going through a stran...
#
#                                              Image
# 0     data/images/44793298_1579175168658123_r.jpeg
# 1      data/images/50669212_1598282954644748_r.jpg
# 2     data/images/47855360_1589149838795170_r.jpeg
# 3     data/images/46073102_1583841007387069_r.jpeg
# 4     data/images/46072754_1583838455417877_r.jpeg
# ...                                            ...
# 6785  data/images/48097994_1589567702790696_r.jpeg
# 6786  data/images/47489998_1587219372600672_r.jpeg
# 6787  data/images/47496222_1588529991103718_r.jpeg
# 6788   data/images/48270674_1594729069827005_r.jpg
# 6789  data/images/47499708_1587250982349137_r.jpeg
#
# [6790 rows x 11 columns]

# %%
print(mydf.iloc[5].Url)

# %% [markdown]
# # Sequential Mode (Online)

# %%
def scrape_all_urls(start = 0, end = len(mydf), file = 'data/GFM_data.csv'):
    finaldf = pd.DataFrame(columns = headers)
    for i in range(start, end):
        try:
            t = scrape_url(i)
            if(type(t) != str):
                finaldf = pd.concat([finaldf,t], ignore_index = True)
            else:
                print(t)
        except Exception as e:
            print(getattr(e, 'message', repr(e)))
    return finaldf
#             try:
#                 sleep(5)
#                 t = scrape_url(i)
#                 temp_df = pd.concat([temp_df,t], ignore_index = True)
#             except:
#                 print("Cant Scrape Row: "+str(i))
                
#     for i in range(start, end):
#         try:
#             temp_df = scrape_url(i)
#             temp_df.to_csv(file, mode = 'a',sep = '\t', header = False)
#         except Exception('ScrapingError'):
#             print("scraping error for row",i)
#         except Exception("InvalidCampaign"):
#             print("Invalid campaign: Row",i)
#         except:
#             try:
#                 sleep(5)
#                 temp_df = scrape_url(i)
#                 temp_df.to_csv(file, mode = 'a',sep = '\t', header = False)
#             except:
#                 print("Cant Scrape Row: ",i)
        
# #             sleep(5)
# #             print("Scraping url %s" %(i+1))
# #             temp_df = scrape_url(i)
# #             temp_df.to_csv(file, mode = 'a',sep = '\t', header = False)

# %%
# Online Mode
_ = pd.DataFrame(columns = headers)
_.to_csv("data/GFM_data.csv",sep = '\t')

data = scrape_all_urls()

# %%
data

# %%
mydf.head().Url

# %%
mydf = pd.read_csv("data/GFM_data.csv",sep = '\t', index_col = 0)
mydf.reset_index(inplace = True, drop = True)
mydf.tail()

# %%
dropDF = mydf[mydf.Text == "We're sorry, but that campaign cannot be found. Please check the link URL and try again."]
print(dropDF.index)
mydf.drop(dropDF.index,axis = 0, inplace = True)
mydf.reset_index(drop = True, inplace = True)
mydf.to_csv("data/GFM_data.csv",sep = '\t')

# %%
print(mydf.shape)
mydf.head(8)

# %%
print(mydf.Url[3],"\n",mydf.Text[127])

# %% [markdown]
# # Rough Work

# %%
row_index = 127

single_row = mydf.iloc[row_index]
url = single_row["Url"]
category = single_row["Category"]
position = single_row["Position"]

page = requests.get(url)
print("URL: ",url)
print("Page: ", page)

# %%
soup = BeautifulSoup(page.text, 'lxml')
# print(soup)
# with open("data/sample_website.html", "w", encoding='utf-8') as file:
#     file.write(str(soup))

# %%
invalidCampaign = soup.find('div', attrs={'class': 'm-campaign-sidebar-notification m-well m-well--sand'})
print(invalidCampaign is not None)

# %%
# Title
soup.find("title").text

# %%
# Organiser
t = soup.find_all("div",{"class":"p-campaign-members"})[0]
# print(t)
print("Organiser: ",t.find_all("div",{"class": "m-person-info-name"})[0].text.replace('\xa0',''))
if(len(t.find_all("div",{"class": "text-small"})) > 2):
    location = t.find_all("div",{"class": "text-small"})[2].text.replace('\xa0','')
else:
    location = t.find_all("div",{"class": "text-small"})[1].text.replace('\xa0','')
print("Location: ",location)
t.find_all("div",{"class": "text-small"})

# %%
# Amount Raised sidebar
t = soup.find("div",{"class":"p-campaign-sidebar"})
amount = t.find("div",{"class": "o-campaign-sidebar-progress-meter m-progress-meter"})
amount.find("h2",{"class":"m-progress-meter-heading"})
print("Amount Raised: ", amount.text.split()[0])
print("Goal: ", amount.text.split()[-2])

print("Number of Donors: ","N/A (yet)")
# t

# %%
# Duration of Fundraising
t = soup.find("div",{"class": "p-campaign-description"})
startDate = ' '.join(t.find("li",{"class": "m-meta-list-item"}).text.split()[1::])
startDate = (pd.to_datetime(startDate)).date()
duration = (pd.datetime.now().date() - startDate).days
print("Start Date: ",startDate,"\nDuration: ",duration)

# %%
# Image
img_container =  soup.find('meta', attrs={'property': 'og:image'})
image_url = img_container['content']

filename = "data/images/"+image_url.split("/")[-1]

# Open the url image, set stream to True, this will return the stream content.
r = requests.get(image_url, stream = True)

# Check if the image was retrieved successfully
if r.status_code == 200:
    # Set decode_content value to True, otherwise the downloaded image file's size will be zero.
    r.raw.decode_content = True
    
    # Open a local file with wb ( write binary ) permission.
#     with open(filename,'wb') as f:
#         shutil.copyfileobj(r.raw, f)
        
    print('Image sucessfully Downloaded: ',filename)
else:
    print('Image Couldn\'t be retreived')

# %%
# All Text
soup.find('div', {'class': "p-campaign-description"})
text = soup.find('div', {'class': "o-campaign-story mt-three-halves"}).text.replace('\xa0','').replace('\n','')
text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-69e00b214915> in <module>
#       1 # All Text
# ----> 2 soup.find('div', {'class': "p-campaign-description"})
#       3 text = soup.find('div', {'class': "o-campaign-story mt-three-halves"}).text.replace('\xa0','').replace('\n','')
#       4 text
#
# NameError: name 'soup' is not defined

# %%
import pandas as pd

file = "data/1.csv"
d = pd.DataFrame({"a":[1,2,3],"b":[7,8,9]})

# %%
d.to_csv(file, index = False)
pd.read_csv(file)
# Out:
#    a  b
# 0  1  7
# 1  2  8
# 2  3  9

# %%
d.to_csv(file, mode = 'a', header = False, index = False)
pd.read_csv(file)
# Out:
#    a  b
# 0  1  7
# 1  2  8
# 2  3  9
# 3  1  7
# 4  2  8
# 5  3  9
