# %% [markdown]
# Location bug still exists...try to filter out <2 words ones?
#
# -*- coding: utf-8 -*-
#
# """
#
# Created on Thu Aug 23, 2020
#
# @author: Rohitashwa
#
# @Credits: loren ( https://github.com/jjeffus/gofundme)
#
# """

# %%
# !pip install selenium
# !pip install bs4
# !pip install requests
# !pip install pytest-shutil

# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from time import sleep
import requests
import re
import shutil # For image download

# %%
mydf = pd.read_csv('data/GFM_url_list.csv', sep = '\t')
headers = ["Url", "Category","Position", "Title", "Location", "Organiser","Amount_Raised", "Goal", "Duration", "Text", "Image"]
mydf = mydf.reindex(columns = headers)
print(mydf.shape)
mydf.tail()
# Out:
# (156, 11)
#                                                    Url Category  Position  \
# 151  https://www.gofundme.com/f/any-help-muc-apprec...   Wishes        10
# 152    https://www.gofundme.com/f/celebrating-rajkumar   Wishes        10
# 153  https://www.gofundme.com/f/conscious-homestead...   Wishes        11
# 154            https://www.gofundme.com/f/nicks-relief   Wishes        11
# 155              https://www.gofundme.com/f/1yxvgqzfuo   Wishes        11
#
#      Title  Location  Organiser  Amount_Raised  Goal  Duration  Text  Image
# 151    NaN       NaN        NaN            NaN   NaN       NaN   NaN    NaN
# 152    NaN       NaN        NaN            NaN   NaN       NaN   NaN    NaN
# 153    NaN       NaN        NaN            NaN   NaN       NaN   NaN    NaN
# 154    NaN       NaN        NaN            NaN   NaN       NaN   NaN    NaN
# 155    NaN       NaN        NaN            NaN   NaN       NaN   NaN    NaN

# %% [markdown]
# # Scrape Individual URLs

# %%
def scrape_url(row_index):
    single_row = mydf.iloc[row_index]
    url = single_row["Url"]
    category = single_row["Category"]
    position = single_row["Position"]
    
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'lxml')
    
    # Description
    text_container =  soup.find('meta', attrs={'name': 'description'})
    try:
        all_text = text_container['content']
    except:
        all_text = np.nan
    
    if(all_text is np.nan )or(all_text == "We're sorry, but that campaign cannot be found. Please check the link URL and try again."):
        temp_df = pd.DataFrame(columns = headers)
        return(temp_df)
    
    # Title
    try:
        title = soup.find("title").text
    except:
        title = np.nan
        
    # Organiser & Location
    try:
        t = soup.find_all("div",{"class":"p-campaign-members"})[0]
        organiser = t.find_all("div",{"class": "m-person-info-name"})[0].text.replace('\xa0','')
        location = ""
        if(len(t.find_all("div",{"class": "text-small"})) > 3):
            location = t.find_all("div",{"class": "text-small"})[2].text.replace('\xa0','')
        else:
            location = t.find_all("div",{"class": "text-small"})[1].text.replace('\xa0','')
    except:
        organiser = np.nan
        location = np.nan
        
    # Amount Raised and Goal
    try:
        t = soup.find("div",{"class":"p-campaign-sidebar"})
        amount = t.find("div",{"class": "o-campaign-sidebar-progress-meter m-progress-meter"})
        amountRaised = amount.text.split()[0]
        goal = amount.text.split()[-2]
    except:
        amountRaised = np.nan
        goal = np.nan
    
    # All Text
    soup.find('div', {'class': "p-campaign-description"})
    text = soup.find('div', {'class': "o-campaign-story mt-three-halves"}).text.replace('\xa0','').replace('\n','')
    text
        
    # Duration of Fundraising
    try:
        t = soup.find("div",{"class": "p-campaign-description"})
        startDate = ' '.join(t.find("li",{"class": "m-meta-list-item"}).text.split()[1::])
        startDate = (pd.to_datetime(startDate)).date()
        duration = (pd.datetime.now().date() - startDate).days
    except:
        duration = np.nan
        
    #Image
    try:
        img_container =  soup.find('meta', attrs={'property': 'og:image'})
        image_url = img_container['content']

        img_filename = "data/images/"+image_url.split("/")[-1]

        # Open the url image, set stream to True, this will return the stream content.
        r = requests.get(image_url, stream = True)

        # Check if the image was retrieved successfully
        if r.status_code == 200:
            # Set decode_content value to True, otherwise the downloaded image file's size will be zero.
            r.raw.decode_content = True

            # Open a local file with wb ( write binary ) permission.
            with open(img_filename,'wb') as f:
                shutil.copyfileobj(r.raw, f)
    except:
        img_filename = np.nan
        
#     # FB likes and Shares    
#     try:
#         FB_shares_container = soup.find_all("strong", {"class":"js-share-count-text"})
#         FB_shares = FB_shares_container[0].text.splitlines()
#         FB_shares = FB_shares[1].replace(" ", "").replace("\xa0", "")
#     except:
#         FB_shares = np.nan
        
#     try:
#         hearts_container = soup.find_all("div", {"class":"campaign-sp campaign-sp--heart fave-num"})
#         hearts = hearts_container[0].text
#     except:
#         hearts = np.nan

    temp_row = np.array([[url, category, position, title, location, organiser, amountRaised, goal, duration, text, img_filename]])
    temp_df = pd.DataFrame(temp_row, columns = headers)
    
    return(temp_df)

# %%
def scrape_all_urls(file = 'data/GFM_data.csv', start = 0, end = len(mydf)):
    for i in range(start, end):
        try:
            temp_df = scrape_url(i)
            temp_df.to_csv(file, mode = 'a',sep = '\t', header = False)
            print("Scraping url %s" %(i+1))
        except:
            sleep(5)
            temp_df = scrape_url(i)
            temp_df.to_csv(file, mode = 'a',sep = '\t', header = False)
            print("Scraping url %s" %(i+1))

# %%
# Online Mode
_ = pd.DataFrame(columns = headers)
_.to_csv("data/GFM_data.csv",sep = '\t')

scrape_all_urls()
# Out:
# <ipython-input-127-5e56c144b08d>:60: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   duration = (pd.datetime.now().date() - startDate).days
# Scraping url 1
# Scraping url 2
# Scraping url 3
# Scraping url 4
# Scraping url 5
# Scraping url 6
# Scraping url 7
# Scraping url 8
# Scraping url 9
# Scraping url 10
# Scraping url 11
# Scraping url 12
# Scraping url 13
# Scraping url 14
# Scraping url 15
# Scraping url 16
# Scraping url 17
# Scraping url 18
# Scraping url 19
# Scraping url 20
# Scraping url 21
# Scraping url 22
# Scraping url 23
# Scraping url 24
# Scraping url 25
# Scraping url 26
# Scraping url 27
# Scraping url 28
# Scraping url 29
# Scraping url 30
# Scraping url 31
# Scraping url 32
# Scraping url 33
# Scraping url 34
# Scraping url 35
# Scraping url 36
# Scraping url 37
# Scraping url 38
# Scraping url 39
# Scraping url 40
# Scraping url 41
# Scraping url 42
# Scraping url 43
# Scraping url 44
# Scraping url 45
# Scraping url 46
# Scraping url 47
# Scraping url 48
# Scraping url 49
# Scraping url 50
# Scraping url 51
# Scraping url 52
# Scraping url 53
# Scraping url 54
# Scraping url 55
# Scraping url 56
# Scraping url 57
# Scraping url 58
# Scraping url 59
# Scraping url 60
# Scraping url 61
# Scraping url 62
# Scraping url 63
# Scraping url 64
# Scraping url 65
# Scraping url 66
# Scraping url 67
# Scraping url 68
# Scraping url 69
# Scraping url 70
# Scraping url 71
# Scraping url 72
# Scraping url 73
# Scraping url 74
# Scraping url 75
# Scraping url 76
# Scraping url 77
# Scraping url 78
# Scraping url 79
# Scraping url 80
# Scraping url 81
# Scraping url 82
# Scraping url 83
# Scraping url 84
# Scraping url 85
# Scraping url 86
# Scraping url 87
# Scraping url 88
# Scraping url 89
# Scraping url 90
# Scraping url 91
# Scraping url 92
# Scraping url 93
# Scraping url 94
# Scraping url 95
# Scraping url 96
# Scraping url 97
# Scraping url 98
# Scraping url 99
# Scraping url 100
# Scraping url 101
# Scraping url 102
# Scraping url 103
# Scraping url 104
# Scraping url 105
# Scraping url 106
# Scraping url 107
# Scraping url 108
# Scraping url 109
# Scraping url 110
# Scraping url 111
# Scraping url 112
# Scraping url 113
# Scraping url 114
# Scraping url 115
# Scraping url 116
# Scraping url 117
# Scraping url 118
# Scraping url 119
# Scraping url 120
# Scraping url 121
# Scraping url 122
# Scraping url 123
# Scraping url 124
# Scraping url 125
# Scraping url 126
# Scraping url 127
# Scraping url 128
# Scraping url 129
# Scraping url 130
# Scraping url 131
# Scraping url 132
# Scraping url 133
# Scraping url 134
# Scraping url 135
# Scraping url 136
# Scraping url 137
# Scraping url 138
# Scraping url 139
# Scraping url 140
# Scraping url 141
# Scraping url 142
# Scraping url 143
# Scraping url 144
# Scraping url 145
# Scraping url 146
# Scraping url 147
# Scraping url 148
# Scraping url 149
# Scraping url 150
# Scraping url 151
# Scraping url 152
# Scraping url 153
# Scraping url 154
# Scraping url 155
# Scraping url 156

# %%
mydf = pd.read_csv("data/GFM_data.csv",sep = '\t', index_col = 0)
mydf.reset_index(inplace = True, drop = True)
mydf.tail()
# Out:
#                                                    Url Category  Position  \
# 129  https://www.gofundme.com/f/any-help-muc-apprec...   Wishes        10
# 130    https://www.gofundme.com/f/celebrating-rajkumar   Wishes        10
# 131  https://www.gofundme.com/f/conscious-homestead...   Wishes        11
# 132            https://www.gofundme.com/f/nicks-relief   Wishes        11
# 133              https://www.gofundme.com/f/1yxvgqzfuo   Wishes        11
#
#                                                  Title              Location  \
# 129  Fundraiser by Tilly Kubany-deane : any help mu...  Scotland Island, NSW
# 130  Fundraiser for Sugeni Ariaratnam by Rajesh Nai...           Fremont, CA
# 131  Fundraiser by Candace Taylor : BIPOC Urban Far...          Winooski, VT
# 132          Fundraiser by Derek Wagner : nicks relief        Providence, RI
# 133  Fundraiser for Lun Dong by Vincent Xiang : For...           Belmont, CA
#
#               Organiser Amount_Raised      Goal  Duration  \
# 129  Tilly Kubany-deane       $40,013   $50,000     324.0
# 130         Rajesh Nair       $39,229   $50,000     195.0
# 131      Candace Taylor       $37,413  $185,000      47.0
# 132        Derek Wagner       $37,129  $200,000     156.0
# 133       Vincent Xiang       $36,621   $50,000     141.0
#
#                                                   Text  \
# 129  Hi everyone,It is with a heavy heart I have be...
# 130  A tribute to our dearest friend Raj Kumar who ...
# 131  Hello Folx! My name is Candace Jennifer and si...
# 132  Hello, my name is Derek Wagner, the chef and o...
# 133  At this trying moment worldwide, we have to ta...
#
#                                             Image
# 129  data/images/42507754_1570268488557534_r.jpeg
# 130  data/images/45419850_1581464729113642_r.jpeg
# 131  data/images/49491282_1594238042716257_r.jpeg
# 132  data/images/46356404_1584852903426154_r.jpeg
# 133   data/images/47190752_1586062466475296_r.jpg

# %%
dropDF = mydf[mydf.Text == "We're sorry, but that campaign cannot be found. Please check the link URL and try again."]
print(dropDF.index)
mydf.drop(dropDF.index,axis = 0, inplace = True)
mydf.reset_index(drop = True, inplace = True)
mydf.to_csv("data/GFM_data.csv",sep = '\t')
# Out:
# Int64Index([], dtype='int64')

# %%
print(mydf.shape)
mydf.head(8)
# Out:
# (134, 11)
#                                                  Url Category  Position  \
# 0  https://www.gofundme.com/f/money-to-buy-hearin...  Medical         0
# 1  https://www.gofundme.com/f/official-navajo-nat...  Medical         1
# 2    https://www.gofundme.com/f/gokalp039a-adim-olun  Medical         2
# 3  https://www.gofundme.com/f/emergenza-covid-ces...  Medical         2
# 4       https://www.gofundme.com/f/save-nil039s-life  Medical         2
# 5  https://www.gofundme.com/f/eric-stevens-care-t...  Medical         3
# 6           https://www.gofundme.com/f/foreva-strong  Medical         3
# 7  https://www.gofundme.com/f/a-better-life-for-l...  Medical         3
#
#                                                Title         Location  \
# 0  Fundraiser by Chandan Shivu Kumar : Money to b...              NaN
# 1  Fundraiser for Pearline Kirk by Navajo Nation ...  Window Rock, AZ
# 2  Fundraiser by Umut Soysal : Gökalp'in kahraman...     Evanston, IL
# 3  Fundraiser by Gloria Zavatta : Cesvi per l'osp...      Team member
# 4     Fundraiser by Berk Atikoğlu : Save Nil's Life!     Brooklyn, NY
# 5  Fundraiser for Eric Stevens by Craig Stevens :...  Los Angeles, CA
# 6  Fundraiser by Ricardo And Jessica Batista : Fo...   North York, ON
# 7  Fundraiser by Team Livie : A Better Life for L...      Team member
#
#                      Organiser Amount_Raised        Goal  Duration  \
# 0                          NaN          $250        $250     221.0
# 1                Navajo Nation    $1,759,060  $1,000,000     112.0
# 2                  Umut Soysal    $1,945,510  $2,400,000     149.0
# 3               Gloria Zavatta    €1,506,000  €1,500,000     167.0
# 4                Berk Atikoğlu    $2,402,780  $2,400,000     167.0
# 5                Craig Stevens    $1,047,750  $1,500,000     320.0
# 6  Ricardo And Jessica Batista    $1,001,830  $2,800,000     318.0
# 7                   Team Livie      €959,533  €1,000,000     108.0
#
#                                                 Text  \
# 0  Hello there, I'm a random guy from India who's...
# 1  The Navajo Nation COVID-19 Fund has been estab...
# 2  (Please scroll down for English and other lang...
# 3  Per aggiornamenti su come stiamo impiegando i ...
# 4  Save Nil’s Life ! I am starting a campaign for...
# 5  Our Little Brother EricI imagine seeing his fu...
# 6  Welcome to ForEva Strong, A donation page dedi...
# 7  We are raising funds for the treatment and car...
#
#                                           Image
# 0  data/images/44793298_1579175168658123_r.jpeg
# 1  data/images/47855360_1589149838795170_r.jpeg
# 2  data/images/47001500_1586119393583256_r.jpeg
# 3  data/images/46073102_1583841007387069_r.jpeg
# 4  data/images/46072754_1583838455417877_r.jpeg
# 5  data/images/42600232_1570640521184863_r.jpeg
# 6  data/images/42600164_1570639439705078_r.jpeg
# 7  data/images/47916028_1588856923726087_r.jpeg

# %%
print(mydf.Url[3],"\n",mydf.Text[127])
# Out:
# https://www.gofundme.com/f/emergenza-covid-cesvi-per-bergamo
#  The intent of this "Go Fund Me" is to raise money for the Vitt Family. Mr. Vitt has expressed a desire to see his biology class get better microscopes, more funding for biology students in the classroom. A long-time dream of Chris's would be to take his beautiful wife to San Salvador. They will also being incurring heavy medical expenses. In every way that this kind gentle man has touched our lives, we have an opportunity to give back to him and to the family he loves. Please consider donating to this worthy cause.

# %% [markdown]
# # Rough Work

# %%
row_index = 127

single_row = mydf.iloc[row_index]
url = single_row["Url"]
category = single_row["Category"]
position = single_row["Position"]

page = requests.get(url)
print("URL: ",url)
print("Page: ", page)
# Out:
# URL:  https://www.gofundme.com/f/vitt-family-support
# Page:  <Response [200]>

# %%
soup = BeautifulSoup(page.text, 'lxml')
# print(soup)
# with open("data/sample1.html", "w", encoding='utf-8') as file:
#     file.write(str(soup))

# %%
# Title
soup.find("title").text
# Out:
# 'Fundraiser for Michelle Vitt by Jeremy Vitt : Vitt Family Support'

# %%
# Organiser
t = soup.find_all("div",{"class":"p-campaign-members"})[0]
# print(t)
print("Organiser: ",t.find_all("div",{"class": "m-person-info-name"})[0].text.replace('\xa0',''))
if(len(t.find_all("div",{"class": "text-small"})) > 2):
    location = t.find_all("div",{"class": "text-small"})[2].text.replace('\xa0','')
else:
    location = t.find_all("div",{"class": "text-small"})[1].text.replace('\xa0','')
print("Location: ",location)
t.find_all("div",{"class": "text-small"})
# Out:
# Organiser:  Jeremy Vitt
# Location:  Beneficiary
# [<div class="text-small">Organizer</div>,
#  <div class="text-small">Hiawatha, KS</div>,
#  <div class="text-small">Beneficiary</div>]

# %%
# Amount Raised sidebar
t = soup.find("div",{"class":"p-campaign-sidebar"})
amount = t.find("div",{"class": "o-campaign-sidebar-progress-meter m-progress-meter"})
amount.find("h2",{"class":"m-progress-meter-heading"})
print("Amount Raised: ", amount.text.split()[0])
print("Goal: ", amount.text.split()[-2])

print("Number of Donors: ","N/A (yet)")
# t
# Out:
# Amount Raised:  $1,759,060
# Goal:  $1,000,000
# Number of Donors:  N/A (yet)

# %%
# Duration of Fundraising
t = soup.find("div",{"class": "p-campaign-description"})
startDate = ' '.join(t.find("li",{"class": "m-meta-list-item"}).text.split()[1::])
startDate = (pd.to_datetime(startDate)).date()
duration = (pd.datetime.now().date() - startDate).days
print("Start Date: ",startDate,"\nDuration: ",duration)
# Out:
# Start Date:  2020-05-04
# Duration:  112
# <ipython-input-53-906245910e0e>:5: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   duration = (pd.datetime.now().date() - startDate).days

# %%
# Image
img_container =  soup.find('meta', attrs={'property': 'og:image'})
image_url = img_container['content']

filename = "data/images/"+image_url.split("/")[-1]

# Open the url image, set stream to True, this will return the stream content.
r = requests.get(image_url, stream = True)

# Check if the image was retrieved successfully
if r.status_code == 200:
    # Set decode_content value to True, otherwise the downloaded image file's size will be zero.
    r.raw.decode_content = True
    
    # Open a local file with wb ( write binary ) permission.
#     with open(filename,'wb') as f:
#         shutil.copyfileobj(r.raw, f)
        
    print('Image sucessfully Downloaded: ',filename)
else:
    print('Image Couldn\'t be retreived')
# Out:
# 'https://d2g8igdw686xgo.cloudfront.net/47641750_1587771177908145_r.jpeg'

# %%
# All Text
soup.find('div', {'class': "p-campaign-description"})
text = soup.find('div', {'class': "o-campaign-story mt-three-halves"}).text.replace('\xa0','').replace('\n','')
text
# Out:
# 'The intent of this "Go Fund Me" is to raise money for the Vitt Family. Mr. Vitt has expressed a desire to see his biology class get better microscopes, more funding for biology students in the classroom. A long-time dream of Chris\'s would be to take his beautiful wife to San Salvador. They will also being incurring heavy medical expenses. In every way that this kind gentle man has touched our lives, we have an opportunity to give back to him and to the family he loves. Please consider donating to this worthy cause.'
